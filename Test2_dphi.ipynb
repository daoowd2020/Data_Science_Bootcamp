# %% [markdown]
# <a href="https://colab.research.google.com/github/daoowd2020/Data_Science_Bootcamp/blob/master/Test2_dphi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sn
pf=pd.read_csv("https://raw.githubusercontent.com/dphi-official/First_ML_Model/master/titanic.csv")
pf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pf.info()

# %%
pf.shape
pf.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
numeric_col=['land_area','percent_city','percent_senior','physicians','hospital_beds','graduates','work_force','income','crime_rate']
corr_matrix = pf.loc[:,numeric_col].corr()
print(corr_matrix)
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income  crime_rate
# land_area            0.081034   0.088728    0.135792  0.111404    0.293907
# percent_city         0.052898   0.076720    0.016011  0.019235    0.159596
# ...

# %%
pf['land_area'].head(5)
# Out:
# 0    1384
# 1    3719
# 2    3553
# 3    3916
# 4    2480
# Name: land_area, dtype: int64

# %%
pf.plot('land_area','crime_rate')

# %%
pf.scatterplot('hospital_beds','physicians')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-f602047f2933> in <module>()
# ----> 1 pf.scatterplot('hospital_beds','physicians')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatterplot'
